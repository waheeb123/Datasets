# %% [markdown]
# **predictive Analysis of FEMA Public Assistance Funding Distribution Across New Jersey Counties**

# %% [markdown]
# ***1. Abstract***
#
# A brief summary (about 200–300 words) describing:
#
# Purpose of the study
#
# Dataset
#
# Statistical methods
#
# Machine learning models
#
# Key findings
#
# Policy implications

# %% [markdown]
# ***2. Introduction***
#
# Topics to cover:
#
# What FEMA Public Assistance (PA) is
#
# Why disaster funding matters
#
# Why New Jersey is an interesting case
#
# Why predicting funding allocation is useful
#
#
#
# Natural disasters such as hurricanes, floods, severe storms, and winter weather events can cause significant damage to public infrastructure, schools, hospitals, utilities, and other critical facilities. In the United States, the Federal Emergency Management Agency (FEMA) plays a central role in supporting disaster recovery through its Public Assistance (PA) Program, which provides financial assistance to state governments, local governments, nonprofit organizations, and certain public entities for eligible disaster-related expenses.
# The FEMA Public Assistance Program funds a wide range of recovery activities, including debris removal, emergency protective measures, and the repair or replacement of damaged public infrastructure. These investments are intended to accelerate community recovery while reducing the financial burden placed on local governments and organizations following federally declared disasters.
# Understanding how FEMA funding is distributed is important for public administrators, emergency managers, and policymakers. Funding allocation may vary according to factors such as project type, applicant type, county, municipality, and the estimated cost of disaster recovery. Examining these patterns can provide valuable insights into resource allocation and improve future planning for disaster preparedness and emergency response.
# This study analyzes FEMA Public Assistance funding data for New Jersey to identify the factors associated with funding allocation and to develop predictive models for estimating obligated funding amounts. In addition to descriptive statistical analysis, this research applies machine learning techniques to evaluate how accurately funding amounts can be predicted using project characteristics. The findings contribute to a better understanding of disaster recovery funding and demonstrate how data science methods can support evidence-based decision-making in emergency management.

# %% [markdown]
# ***3. Literature Review***
#
# Review previous studies on
#
# Disaster recovery funding
#
# FEMA allocation policies
#
# Emergency management
#
# Government spending prediction
#
# Machine learning in public administration
#
# FEMA Public Assistance Program
# The Federal Emergency Management Agency (FEMA) Public Assistance (PA) Program is one of the primary federal disaster recovery programs in the United States. It provides financial assistance to state governments, local governments, tribal governments, and eligible nonprofit organizations following presidentially declared disasters. The program supports emergency response activities, debris removal, emergency protective measures, and the repair, restoration, or replacement of damaged public infrastructure. By reducing the financial burden on local communities, the PA Program helps accelerate disaster recovery and improve community resilience.
# Disaster Recovery Funding
# Effective disaster recovery depends heavily on the timely and equitable distribution of financial resources. Previous studies have shown that federal disaster assistance plays a significant role in restoring infrastructure, maintaining essential public services, and supporting long-term economic recovery. However, researchers have also found that funding allocation often varies according to disaster severity, geographic location, applicant characteristics, and administrative processes. These variations have motivated ongoing research into improving the transparency and efficiency of disaster funding.
# Data Analytics and Machine Learning in Emergency Management
# Recent advances in data science have enabled government agencies and researchers to analyze large disaster-related datasets using statistical and machine learning techniques. Predictive models such as linear regression, decision trees, random forests, and gradient boosting have been applied to estimate disaster losses, forecast emergency resource needs, and predict recovery costs. Compared with traditional statistical methods, machine learning models are capable of identifying complex nonlinear relationships among variables and often produce more accurate predictions.
# Funding Allocation Factors
# Several characteristics influence FEMA funding decisions, including project type, applicant type, disaster category, geographic location, and the estimated cost of eligible damages. Previous research has suggested that larger infrastructure projects generally receive higher levels of federal assistance, while funding distributions may differ among counties, municipalities, nonprofit organizations, and state agencies. Understanding these factors is important for improving disaster preparedness and ensuring equitable allocation of recovery resources.
# Research Gap
# Although numerous studies have examined disaster recovery and FEMA assistance at the national level, relatively few have focused specifically on New Jersey Public Assistance funding using modern data science techniques. Existing research often emphasizes policy evaluation rather than predictive modeling. Furthermore, limited attention has been given to identifying the variables that most strongly influence obligated funding amounts or comparing the performance of different machine learning algorithms for predicting FEMA funding allocations.
# This study addresses these gaps by analyzing FEMA Public Assistance funding data for New Jersey. Using exploratory data analysis, statistical methods, and machine learning models, the project investigates funding patterns across counties, municipalities, applicant types, and project categories while developing predictive models for estimating obligated funding amounts.

# %% [markdown]
# 4. Research Questions
# For example:
# Which factors most influence FEMA funding amounts?
# Can we accurately predict the obligated funding amount?
# Do counties receive significantly different funding?
# Which project types receive the highest funding?
# Does applicant type affect funding?
#
#
#
# What factors are associated with higher FEMA Public Assistance obligated funding amounts in New Jersey?
# Can machine learning models accurately predict the obligated amount of FEMA Public Assistance projects based on project characteristics?
# How do funding allocations vary across counties, municipalities, applicant types, and project categories?
# Which project characteristics are the most important predictors of FEMA funding?

# %% [markdown]
# 5. Data Sources
# Describe the dataset.
# Variables include
# County
# Municipality
# Applicant
# Federal Agency
# Project Type
# Funding Source
# Obligated Amount
# Federal Share
# Local Share
# Dates
# Mention that the dataset comes from FEMA/NJ Open Data.
#
#
# Data Sources
# This study uses the New Jersey Federal Grants and Disaster Assistance Dataset, which contains detailed records of disaster recovery funding provided through federal agencies. The dataset includes information on funding allocations, project characteristics, applicant organizations, geographic locations, and financial contributions associated with federally supported disaster recovery projects in New Jersey.
# The analysis focuses on funding awarded through the Federal Emergency Management Agency (FEMA) Public Assistance (PA) Program, which provides financial assistance to eligible public entities and nonprofit organizations for disaster-related recovery activities. These activities include debris removal, emergency protective measures, and the repair or replacement of damaged public infrastructure.
# The dataset contains both categorical and numerical variables that describe each funded project. Key variables used in this study include:
# Dependent Variable
# Obligated Amount – The total amount of federal funding obligated for each project.
# Independent Variables
# Federal Agency
# Funding Source
# Program Description
# Project
# Project Description
# Project Type
# County
# Municipality
# Applicant
# Federal Share
# State Share
# Local Share
# Obligated Date
# Federal Disbursed Amount
# Federal Disbursed Date
# These variables provide information about the characteristics of funded projects and are used to examine factors associated with funding allocation and to develop predictive models for estimating obligated funding amounts.
# The dataset represents publicly available government records and provides a valuable resource for understanding disaster recovery investments across New Jersey. Because the data originate from official government reporting, they offer a reliable basis for statistical analysis, predictive modeling, and policy evaluation.

# %% [markdown]
# 6. Data Preparation and Cleaning
# Exactly like your previous project.
#
#
# Now we start the actual data science work in RStudio.
# This section will include:
# Importing the dataset
# Loading required libraries
# Cleaning column names
# Converting currency values (e.g., $2,431.15 → 2431.15)
# Converting date variables
# Handling missing values
# Removing duplicates
# Checking data types
# Creating a clean dataset for analysis
#
# Before performing statistical analysis and predictive modeling, the dataset must be cleaned and transformed into a format suitable for analysis. Data preparation includes importing the dataset, handling missing values, converting variables into appropriate data types, cleaning financial fields, and preparing new variables for modeling. These steps help ensure data quality and improve the accuracy of subsequent analyses.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('https://github.com/waheeb123/Datasets/blob/main/Sandy_PA_Master_Data_20260721.csv?raw=true')

# %%
df.head()
# Out:
#    As Of Date Federal Agency Funding Source  \
# 0  04/22/2026        FEMA PA             PA
# 1  04/22/2026        FEMA PA             PA
# 2  04/22/2026        FEMA PA             PA
# 3  04/22/2026        FEMA PA             PA
# 4  04/22/2026        FEMA PA             PA
#
#                                  Program Description             Project  \
# 0  Federal Emergency Management Agency's (FEMA) P...  A - Debris Removal
# 1  Federal Emergency Management Agency's (FEMA) P...  A - Debris Removal
# 2  Federal Emergency Management Agency's (FEMA) P...  A - Debris Removal
# 3  Federal Emergency Management Agency's (FEMA) P...  A - Debris Removal
# 4  Federal Emergency Management Agency's (FEMA) P...  A - Debris Removal
#
#                                  Project Description             Project Type  \
# 0  This program provides funding for the clearanc...  Non-Profit Organization
# 1  This program provides funding for the clearanc...  Non-Profit Organization
# ...

# %%
money_columns = [
    "Obligated Amount",
    "Federal Share",
    "Local Share",
    "Federal Disbursed Amount"
]

for col in money_columns:
    df[col] = df[col].astype(str)
    df[col] = (
        df[col]
        .str.replace("$", "", regex=False)
        .str.replace(",", "", regex=False)
    )
    df[col] = pd.to_numeric(df[col], errors="coerce")

# %%
date_columns = ["As Of Date", "Obligated Date", "Federal Disbursed Date"]
for col in date_columns:
    df[col] = pd.to_datetime(df[col], errors="coerce")

# %%
df = df.drop_duplicates()

# %%
# Extract year and month from Obligated Date
df['Obligated Year'] = df['Obligated Date'].dt.year
df['Obligated Month'] = df['Obligated Date'].dt.month

# %%
# Calculate Federal Share ratio
df['Federal_Ratio'] = df['Federal Share'] / df['Obligated Amount']

# Calculate Local Share ratio
df['Local_Ratio'] = df['Local Share'] / df['Obligated Amount']

# %%
# Extract project category
df['Project_Category'] = df['Project'].str.extract(r'^([A-Z])')[0]

# %%
def categorize_applicant(app_name):
    if isinstance(app_name, str):
        if 'County' in app_name:
            return 'County'
        elif 'Borough' in app_name or 'Township' in app_name or 'City' in app_name:
            return 'Municipality'
        elif 'Board of Education' in app_name:
            return 'School District'
        elif 'Nonprofit' in app_name or 'Aids' in app_name:
            return 'Non-Profit'
        else:
            return 'Other'
    return 'Other'

df['Applicant_Category'] = df['Applicant'].apply(categorize_applicant)

# %%
def funding_size(amount):
    if amount <= 10000:
        return 'Small (<$10K)'
    elif amount <= 100000:
        return 'Medium ($10K-$100K)'
    elif amount <= 1000000:
        return 'Large ($100K-$1M)'
    else:
        return 'Very Large (>$1M)'

df['Funding_Size'] = df['Obligated Amount'].apply(funding_size)

# %%
features = [
    'Project Type', 'County', 'Municipality', 'Applicant_Category',
    'Obligated Year', 'Obligated Month', 'Federal Share',
    'Local Share', 'Federal_Ratio', 'Project_Category'
]
target = 'Obligated Amount'

# %%
# Drop rows with missing target values
df_model = df.dropna(subset=[target])

# Fill missing values in features
df_model['Federal Share'] = df_model['Federal Share'].fillna(0)
df_model['Local Share'] = df_model['Local Share'].fillna(0)
df_model['Federal_Ratio'] = df_model['Federal_Ratio'].fillna(0)

# %%
# Identify categorical columns
categorical_cols = [
    'Project Type', 'County', 'Municipality',
    'Applicant_Category', 'Project_Category'
]

# Create dummy variables
X = pd.get_dummies(df_model[features], columns=categorical_cols, drop_first=True)
y = df_model[target]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)

# %% [markdown]
# 7. Feature Engineering
# Instead of PSA scores, this section becomes
# Feature Engineering
# Create variables like
# Year
# Month
# Funding Ratio
# Federal_Ratio =
# Federal_Share / Obligated_Amount
# Project categories
# Applicant categories
# County indicators
# Funding size categories
# 8. Final Modeling Dataset
# Prepare variables
# Convert categorical variables
# Dummy encoding
# Train/Test split
# 80/20
# Exactly like your PSA project.
# 9. Data Exploration
# Include
# Summary statistics
# Funding distribution
# Top counties
# Top municipalities
# Top applicants
# Project types
# Funding source
# Average funding
# Median funding
# Outliers
# Visualizations
# Histograms
# Boxplots
# County bar charts
# Project type charts
# 10. Correlation Analysis
# Correlation between
# Federal Share
# Local Share
# Funding Amount
# Heatmap
# Scatterplots
# Correlation matrix
# 11. Predictive Modeling
# Predict
# Obligated Amount
# Models
# Linear Regression
# Random Forest
# XGBoost (optional)
# Decision Tree
# Evaluation
# RMSE
# MAE
# R²
# Feature importance
# 12. Fairness / Equity Analysis
# Instead of racial fairness, analyze geographic and organizational equity.
# Examples
# Which counties receive more funding?
# Funding by applicant type
# Non-Profit vs County vs Municipality
# Rural vs Urban (if available)
# This keeps the same analytical depth while fitting the dataset.
# 13. Discussion
# Interpret
# Counties receiving the largest allocations
# Most expensive project categories
# Importance of federal share
# Predictive model performance
# Practical implications
# 14. Conclusion
# Summarize
# Main findings
# Policy recommendations
# Limitations
# Future research
# 15. References
# Include references from
# FEMA
# New Jersey Open Data
# Emergency management journals
# Machine learning references
# Expected Visualizations
# I recommend including approximately 12–15 figures:
# Funding distribution histogram
# Funding boxplot
# Top 10 counties by funding
# Top project types
# Funding by applicant type
# Federal vs local share scatterplot
# Correlation heatmap
# Monthly funding trend
# Yearly funding trend
# Random Forest feature importance
# Linear Regression residual plot
# Predicted vs actual funding
# RMSE comparison across models
# County funding map (optional)
# Funding by municipality (optional)
# Why this project is strong
# Compared to your PSA project, this topic is:
# Easier to explain to a general audience.
# Rich in opportunities for exploratory data analysis and predictive modeling.
# Well suited to regression techniques.
# Highly relevant to public administration, emergency management, and government policy.
# An excellent portfolio project for data science and analytics roles.
# I recommend following this structure almost identically to your previous report, replacing the PSA-specific methodology with feature engineering and replacing the fairness analysis with equity analysis of FEMA funding across counties and applicant types. This will produce a polished, publication-style report while remaining appropriate for the FEMA dataset.
